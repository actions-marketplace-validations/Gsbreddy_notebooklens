# %% [markdown]
# ## Churn model training
# This notebook trains the churn model and reports the latest accuracy.

# %%
dataset_path = "train_v2.csv"
seed = 7

# %%
accuracy = 0.73
accuracy
# Out:
# 0.73
