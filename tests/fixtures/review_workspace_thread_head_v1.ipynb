# %% [markdown]
# # Churn Model Training
# This notebook trains the baseline churn model on the original training split.

# %%
import pandas as pd
train_df = pd.read_csv("train_v2.csv")

# %%
seed = 7

# %%
accuracy = evaluate_model(train_df, seed)
print(f"accuracy = {accuracy:.2f}")
# Out:
# accuracy = 0.73
