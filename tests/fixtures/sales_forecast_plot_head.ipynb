# %% [markdown]
# # Weekly Sales Forecast
# Baseline weekly sales forecast for the North America planning review.

# %%
import pandas as pd
sales = pd.read_csv("sales_q2.csv")

# %%
window = 8
forecast = fit_sales_forecast(sales, window=window)
plot_sales_forecast(forecast)

# %%
mae = evaluate_forecast(forecast)
print(f"mae = {mae:.1f}")
# Out:
# mae = 18.7\n
